# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Pandas: veri analizi ve işleme
# Matplotlib: veri görselleştirme
# Seaborn: istatistiksel veri görselleştirme

# %%
data = pd.read_csv("../athlete_events.csv")  #eğer çekeceğimiz data bir üst klasörde ise başına .. koyarız

# %%
data.describe()   #Bu komut sayısal sütunların istatistiksel özetini çıkarıyor.
#count → kaç tane boş olmayan değer var
#mean  → ortalama
#std   → standart sapma
#min   → en küçük değer
#25%   → 1. çeyrek
#50%   → medyan
#75%   → 3. çeyrek
#max   → en büyük değer
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
data.head() #Veri setinin ilk 5 satırını gösterir.

#data.head(10) dersen ilk 10 satırı gösterir.
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.columns #DataFrame'deki bütün sütun isimlerini gösterir.

#() yok. Çünkü columns bir özellik (attribute), fonksiyon değil.
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data.isnull() #DataFrame'deki her hücre için:Burada eksik veri var mı?

# isnull(): her hücrede eksik (NaN) veri olup olmadığını kontrol eder
# True = eksik veri var, False = veri var
# Out:
#            ID   Name    Sex    Age  Height  Weight   Team    NOC  Games  \
# 0       False  False  False  False   False   False  False  False  False
# 1       False  False  False  False   False   False  False  False  False
# 2       False  False  False  False    True    True  False  False  False
# 3       False  False  False  False    True    True  False  False  False
# 4       False  False  False  False   False   False  False  False  False
# ...       ...    ...    ...    ...     ...     ...    ...    ...    ...
# 271111  False  False  False  False   False   False  False  False  False
# 271112  False  False  False  False   False   False  False  False  False
# 271113  False  False  False  False   False   False  False  False  False
# 271114  False  False  False  False   False   False  False  False  False
# 271115  False  False  False  False   False   False  False  False  False
#
#          Year  Season   City  Sport  Event  Medal
# 0       False   False  False  False  False   True
# ...

# %%
data.isnull().sum()   #her sütunda kaç eksik veri olduğunu söyler.
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
data.info()

#RangeIndex: 271116 entries---Data columns (total 15 columns)  271.116 satır ,15 sütun var demek.

#261642 non-null Age sütununda 261.642 tane boş olmayan değer var. (Diğerleri içinde bu şekilde name için şu kadar null var falan gibi)
#271116 toplam satır bu olduğuna göre demekki eksik veri var bunda azsa

#Name yazı olduğu için object.

# info(): satır/sütun sayısını, eksik olmayan değerleri, veri tiplerini ve bellek kullanımını gösterir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
plt.scatter("Height", "Weight", data=data)
#plt.scatter(data["Height"], data["Weight"]) Normalde böyle yapabilirdik.

#ama data=data dediğimiz için sütun isimlerini doğrudan verebiliyorum.

# scatter(): iki sayısal değişken arasındaki ilişkiyi noktalar halinde gösterir

# X = Height, Y = Weight


plt.xlabel("Height") # xlabel(): X ekseninin başlığını belirler

plt.ylabel("Weight") # ylabel(): Y ekseninin başlığını belirler

plt.title("Athelete Weight vs Height") # title(): grafiğe başlık ekler

plt.show() # show(): oluşturulan grafiği ekranda gösterir
